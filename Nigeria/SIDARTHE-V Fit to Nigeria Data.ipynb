# %%
# import libaries

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from numpy import exp, linspace, random
from scipy.optimize import curve_fit
#from lmfit import Model
from matplotlib import gridspec

from scipy import integrate, optimize
import datetime as dt
import matplotlib.dates as mdates
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from scipy.interpolate import interp1d

# %%
# load data
data=pd.read_csv("COVID19_Data_for_Nigeria.csv")
data
# Out:
#           date  Goodnessfit  daily  confirmed_cases  active_cases  Recovered  \
# 0    2/28/2020            1      0                1             1          0
# 1    2/29/2020            1      1                1             1          0
# 2     3/1/2020            1      2                1             1          0
# 3     3/2/2020            1      3                1             1          0
# 4     3/3/2020            1      4                1             1          0
# ..         ...          ...    ...              ...           ...        ...
# 719  2/16/2022            1    719           254137         20517     230479
# 720  2/17/2022            1    720           254182         20511     230530
# 721  2/18/2022            1    721           254221         20530     230549
# 722  2/19/2022            1    722           254243         20514     230587
# 723  2/20/2022            1    723           254293         20396     230755
#
#      total_deaths  total_tests  one dose of vacination  fully_vaccinated  ...  \
# 0               0          NaN                     NaN               NaN  ...
# 1               0          NaN                     NaN               NaN  ...
# 2               0          NaN                     NaN               NaN  ...
# 3               0          NaN                     NaN               NaN  ...
# 4               0          NaN                     NaN               NaN  ...
# ..            ...          ...                     ...               ...  ...
# 719          3141    4177940.0              14834559.0         5446849.0  ...
# 720          3141    4177940.0              14834559.0         5446849.0  ...
# 721          3142    4177940.0              14834559.0         5446849.0  ...
# 722          3142    4177940.0              14834559.0         5446849.0  ...
# 723          3142    4177940.0              14834559.0         5446849.0  ...
#
#      confirmed_cases_log  active_cases_log  discharged_cases_log  \
# 0               0.000000          0.000000                   NaN
# 1               0.000000          0.000000                   NaN
# 2               0.000000          0.000000                   NaN
# 3               0.000000          0.000000                   NaN
# 4               0.000000          0.000000                   NaN
# ..                   ...               ...                   ...
# 719             5.405068          4.312114              5.362631
# 720             5.405145          4.311987              5.362727
# 721             5.405211          4.312389              5.362763
# 722             5.405249          4.312050              5.362835
# 723             5.405334          4.309545              5.363151
#
#      total_deaths_log  one dose of vacination_log  fully_vaccinated_log  Days  \
# 0                 NaN                         NaN                   NaN   NaN
# 1                 NaN                         NaN                   NaN   NaN
# 2                 NaN                         NaN                   NaN   NaN
# 3                 NaN                         NaN                   NaN   NaN
# 4                 NaN                         NaN                   NaN   NaN
# ..                ...                         ...                   ...   ...
# 719          3.497068                    7.171275              6.736145   NaN
# 720          3.497068                    7.171275              6.736145   NaN
# 721          3.497206                    7.171275              6.736145   NaN
# 722          3.497206                    7.171275              6.736145   NaN
# 723          3.497206                    7.171275              6.736145   NaN
#
#      Fration_one dose of vacination  Fration_fully_vaccinated  \
# 0                          0.000000                  0.000000
# 1                          0.000000                  0.000000
# 2                          0.000000                  0.000000
# 3                          0.000000                  0.000000
# 4                          0.000000                  0.000000
# ..                              ...                       ...
# 719                        0.068362                  0.025101
# 720                        0.068362                  0.025101
# 721                        0.068362                  0.025101
# 722                        0.068362                  0.025101
# 723                        0.068362                  0.025101
#
#      Fration_total_vaccinations
# 0                      0.000000
# 1                      0.000000
# 2                      0.000000
# 3                      0.000000
# 4                      0.000000
# ..                          ...
# 719                    0.093463
# 720                    0.093463
# 721                    0.093463
# 722                    0.093463
# 723                    0.093463
#
# [724 rows x 22 columns]

# %%
data_time=data['daily']

# %%
# parameters
def rzero( t,par): 

    alpha   = par[0]
    beta    = par[1]
    delta   = par[2]
    gamma   = par[3]
    epsilon = par[4]
    zeta    = par[5]
    lamda   = par[6]
    eta     = par[7]
    rho     = par[8]
    theta   = par[9]
    mu      = par[10]
    kappa   = par[11]
    nu      = par[12]
    chi     = par[13]
    sigma   = par[14]
    tau_a   = par[15]
    tau_b   = par[16]
    alpha_p = par[17]
    phi     = par[18]

      # Parameters
    r1=epsilon+zeta+lamda
    r2=eta+rho
    r3=theta+mu+kappa
    r4=nu+chi
    r5=sigma+tau_b

      # Initial R0
    R0_initial=alpha/r1+beta*epsilon/(r1*r2)+gamma*zeta/(r1*r3)+delta*eta*epsilon/(r1*r2*r4)
    + delta*zeta*theta/(r1*r3*r4)

    R0 = R0_initial;
    
    plottato = 0; 
    plottato1 = 0; 
    plottato_bis = 0;
    plottato_tris = 0; 
    plottato_quat = 0; 
    plottato4A = 0;
    plottato5 = 0;  
    plottato6 = 0; 
    plottato6A = 0;
    plottato7 = 0;  
    plottato8 = 0;
    plottato9 = 0;
    plottatoA = 0;
    plottatoB = 0;
    plottatoC = 0;
    plottatoD = 0;
    plottatoE = 0;
    plottatoF = 0;
    plottatoG = 0;
    plottatoH = 0;
    plottatoI = 0;
    plottatoJ = 0;
    plottatoK = 0;    
    plottatoL = 0;    
    plottatoM = 0;  
    plottatoN = 0;
    plottatoO = 0;
    plottatoP = 0;
    plottatoP1 = 0;
    plottatoQ = 0;
    plottatoQ1 = 0;
    plottatoR = 0;
    plottatoS = 0;
    plottatoT = 0;
    plottatoU = 0;    
    plottatoV = 0;    
    plottatoW = 0;    
    plottatoY = 0;    
    plottatoX = 0;    
    plottatoZ = 0; 
    plottatoS1 = 0;
    plottatoR1 = 0;
    plottatoT1 = 0;
    plottatoU1 = 0 ;
    plottatoV1 = 0;    
    plottatoW1 = 0;    
    plottatoY1 = 0;    
    plottatoX1 = 0;    
    plottatoZ1 = 0;
    plottatoZ11 = 0;
    plottatoZ2 = 0;    
    plottatoK1 = 0    
    
    
    
    
    if (t<450):
        tau_a   = 0.00
        phi     = 0.00
        alpha_p = 0.00    
    
    if (t >= 0 ):
        alpha= 0.01 #0.48 0.4218;
        gamma= 0.01 #0.38 #0.285;
        beta = 0.01 #0.025 #0.0057;
        delta= 0.01#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.642
        nu=0.653
        zeta=0.6532
        eta=0.6532
        epsilon=0
        theta=0
        rho=0.0
        kappa=0.0
        chi=0.0
        sigma=0.0
        tau_b=0.0    
            
        if (plottato == 0):# { // Compute the new R0            
            r1=epsilon+zeta+lamda            
            r2=eta+rho
            r3=theta+mu+kappa
            r4=nu+chi            
            r5=sigma+tau_b            
            R0_primemisure=alpha/r1+beta*epsilon/(r1*r2)+gamma*zeta/ (r1*r3)+delta*eta*epsilon/(r1*r2*r4)
            +delta*zeta*theta/(r1*r3*r4)           
            plottato = 1          
            R0 = R0_primemisure  
            

    if (t>10): #// Social distancing: lockdown, mild effect 
        alpha= 0.8 #0.48 0.4218;
        gamma= 0.8 #0.38 #0.285;
        beta = 0.8 #0.025 #0.0057;
        delta= 0.8#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0
        theta=0
        rho=0.0
        kappa=0.0
        chi=0.0
        sigma=0.0
        tau_b=0.0       
               
                     
        if (plottato_bis == 0): #Compute the new R0            
            r1=epsilon+zeta+lamda            
            r2=eta+rho            
            r3=theta+mu+kappa           
            r4=nu+chi           
            r5=sigma+tau_b          
            R0_secondemisure=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2* r4+delta*eta*epsilon*r3
            +delta*zeta*theta*r2)/(r1*r2*r3*r4)            
            plottato_bis = 1           
            R0 = R0_secondemisure            
 
    if (t>20): #// Social distancing: lockdown, mild effect 
        alpha= 0.2 #0.48 0.4218;
        gamma= 0.2 #0.38 #0.285;
        beta = 0.2 #0.025 #0.0057;
        delta= 0.2#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0
        theta=0
        rho=0.0
        kappa=0.0
        chi=0.0
        sigma=0.0
        tau_b=0.03
               
                     
        if (plottato_tris == 0):# { // Compute the new R0          
            r1=epsilon+zeta+lamda           
            r2=eta+rho            
            r3=theta+mu+kappa            
            r4=nu+chi           
            r5=sigma+tau_b         
            R0_terzemisure=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4 
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4)           
            plottato_tris = 1           
            R0 = R0_terzemisure           
             
    if (t>25): #// Social distancing: lockdown, mild effect 
        alpha= 0.2 #0.48 0.4218;
        gamma= 0.2 #0.38 #0.285;
        beta = 0.2 #0.025 #0.0057;
        delta= 0.2#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0
        theta=0
        rho=0.0
        kappa=0.0
        chi=0.0
        sigma=0.0
        tau_b=0.0001                
        if (plottato_quat == 0 ): #{ // Compute the new R0          
            r1=epsilon+zeta+lamda;          
            r2=eta+rho;           
            r3=theta+mu+kappa;           
            r4=nu+chi;           
            r5=sigma+tau_b        
            R0_quartemisure=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4);           
            plottato_quat = 1         
            R0 = R0_quartemisure 

    if (t>30): # { // Broader diagnosis campaign               
        alpha= 0.2 #0.48 0.4218;
        gamma= 0.2 #0.38 #0.285;
        beta = 0.2 #0.025 #0.0057;
        delta= 0.2#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0
        theta=0
        rho=0.0
        kappa=0.0
        chi=0.0
        sigma=0.0
        tau_b=0.005  

        if (plottato1 == 0 ): #{ // Compute the new R0          
            r1=epsilon+zeta+lamda;          
            r2=eta+rho;           
            r3=theta+mu+kappa;           
            r4=nu+chi;           
            r5=sigma+tau_b;         
            R0_quartemisure=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4);           
            plottato1 = 1         
            R0 = R0_quartemisure             
            
    if (t>34): # { // Broader diagnosis campaign               
       
        alpha= 0.0512 #0.48 0.4218;
        gamma= 0.0512 #0.38 #0.285;
        beta = 0.0512 #0.025 #0.0057;
        delta= 0.0512#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0.039
        theta=0.039
        rho=0.039
        kappa=0.039
        chi=0.039
        sigma=0.039
        tau_b=0.004 
    

        if (plottato4A == 0 ): #{ // Compute the new R0          
            r1=epsilon+zeta+lamda;          
            r2=eta+rho;           
            r3=theta+mu+kappa;           
            r4=nu+chi;           
            r5=sigma+tau_b;         
            R0_quartemisure=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4);           
            plottato4A = 1         
            R0 = R0_quartemisure 
            
    if (t>42):# { // Broader diagnosis campaign        
        alpha= 0.3 #0.48 0.4218;
        gamma= 0.3#0.38 #0.285;
        beta = 0.3 #0.025 #0.0057;
        delta= 0.3#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0.039
        theta=0.039
        rho=0.049
        kappa=0.049
        chi=0.049
        sigma=0.049
        tau_b=0.007
        if (plottato5 == 0 ): # { // Compute the new R0          
            r1=epsilon+zeta+lamda;           
            r2=eta+rho;            
            r3=theta+mu+kappa;       
            r4=nu+chi;            
            r5=sigma+tau_b;
            R0_quartemisure=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4);            
            plottato5 = 1;           
            R0 = R0_quartemisure
            
            

    if (t>50): #{ // Broader diagnosis campaign      
        alpha= 0.16 #0.48 0.4218;
        gamma= 0.16#0.38 #0.285;
        beta = 0.16 #0.025 #0.0057;
        delta= 0.16#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0.039
        theta=0.039
        rho=0.01
        kappa=0.01
        chi=0.01
        sigma=0.01
        tau_b=0.007  
        if (plottato4A == 0 ): # { // Compute the new R0            
            r1=epsilon+zeta+lamda;           
            r2=eta+rho;           
            r3=theta+mu+kappa;          
            r4=nu+chi;            
            r5=sigma+tau_b;           
            R0_quartemisures=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4);    
            plottato4A = 1;           
            R0 = R0_quartemisures   

    if (t>60): #{ // Broader diagnosis campaign
        
        alpha= 0.19 #0.48 0.4218;
        gamma= 0.19#0.38 #0.285;
        beta = 0.19 #0.025 #0.0057;
        delta= 0.19#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0.039
        theta=0.039
        rho=0.02
        kappa=0.02
        chi=0.02
        sigma=0.02
        tau_b=0.006      
        
        

        if (plottato5 == 0 ): # { // Compute the new R0            
            r1=epsilon+zeta+lamda;           
            r2=eta+rho;           
            r3=theta+mu+kappa;          
            r4=nu+chi;            
            r5=sigma+tau_b;           
            R0_quartemisure=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4);    
            plottato5 = 1;           
            R0 = R0_quartemisure            
            
    if (t>71): #{ // Social distancing: lockdown, strong effect           
        alpha= 0.0253 #0.48 0.4218;
        gamma= 0.0253#0.38 #0.285;
        beta = 0.0253 #0.025 #0.0057;
        delta= 0.0253#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0.039
        theta=0.039
        rho=0.02
        kappa=0.02
        chi=0.02
        sigma=0.02
        tau_b=0.002
        if (plottato7 == 0):# { // Compute the new R0          
            r1=epsilon+zeta+lamda           
            r2=eta+rho            
            r3=theta+mu+kappa            
            r4=nu+chi           
            r5=sigma+tau_b           
            R01=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4 
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4)           
            plottato7 = 1           
            R0 = R01 
            
            
    if (t>79): #{ // Social distancing: lockdown, strong effect           
        alpha= 0.15#0.48 0.4218;
        gamma= 0.15#0.38 #0.285;
        beta = 0.15 #0.025 #0.0057;
        delta= 0.15#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0.039
        theta=0.039
        rho=0.02
        kappa=0.02
        chi=0.02
        sigma=0.02
        tau_b=0.0015
        if (plottatoK == 0):# { // Compute the new R0          
            r1=epsilon+zeta+lamda           
            r2=eta+rho            
            r3=theta+mu+kappa            
            r4=nu+chi           
            r5=sigma+tau_b           
            R0K=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4 
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4)           
            plottatoK = 1           
            R0 = R0K  
            
            
    if (t>109): #{ // Social distancing: lockdown, strong effect
        
        alpha= 0.104#0.48 0.4218;
        gamma= 0.104#0.38 #0.285;
        beta = 0.104 #0.025 #0.0057;
        delta= 0.104#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0.039
        theta=0.039
        rho=0.017
        kappa=0.017
        chi=0.017
        sigma=0.017
        tau_b=0.00067      
        
        
        if (plottatoK == 0):# { // Compute the new R0          
            r1=epsilon+zeta+lamda           
            r2=eta+rho            
            r3=theta+mu+kappa            
            r4=nu+chi           
            r5=sigma+tau_b           
            R0K=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4 
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4)           
            plottatoK = 1           
            R0 = R0K



    if (t>155): #{ // Social distancing: lockdown, strong effect           
        alpha= 0.001#0.48 0.4218;
        gamma= 0.001#0.38 #0.285;
        beta = 0.001 #0.025 #0.0057;
        delta= 0.001#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0.039
        theta=0.039
        rho=0.25
        kappa=0.25
        chi=0.25
        sigma=0.25
        tau_b=0.00067 
        if (plottato7 == 0):# { // Compute the new R0          
            r1=epsilon+zeta+lamda           
            r2=eta+rho            
            r3=theta+mu+kappa            
            r4=nu+chi           
            r5=sigma+tau_b           
            R01=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4 
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4)           
            plottato7 = 1           
            R0 = R01             
                        
    if (t>157): #{ // Social distancing: lockdown, strong effect           
        alpha= 0.42#0.48 0.4218;
        gamma= 0.42#0.38 #0.285;
        beta = 0.42#0.025 #0.0057;
        delta= 0.42#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0.039
        theta=0.039
        rho=0.1
        kappa=0.1
        chi=0.1
        sigma=0.1
        tau_b=0.00067
        ; 
        if (plottatoA == 0):# { // Compute the new R0          
            r1=epsilon+zeta+lamda           
            r2=eta+rho            
            r3=theta+mu+kappa            
            r4=nu+chi           
            r5=sigma+tau_b           
            R03=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4 
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4)           
            plottatoA = 1           
            R0 = R03              

            
    if (t>160): #{ // Social distancing: lockdown, strong effect           
        alpha= 0.12#0.48 0.4218;
        gamma= 0.12#0.38 #0.285;
        beta = 0.12#0.025 #0.0057;
        delta= 0.12#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0.039
        theta=0.038
        rho=0.07
        kappa=0.07
        chi=0.07
        sigma=0.07
        tau_b=0.00067 
        if (plottatoL == 0):# { // Compute the new R0          
            r1=epsilon+zeta+lamda           
            r2=eta+rho            
            r3=theta+mu+kappa            
            r4=nu+chi           
            r5=sigma+tau_b           
            R0L=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4 
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4)           
            plottatoL = 1           
            R0 = R0L             
            
            
    if (t>170): #{ // Social distancing: lockdown, strong effect           
        alpha= 0.01#0.48 0.4218;
        gamma= 0.01#0.38 #0.285;
        beta = 0.01#0.025 #0.0057;
        delta= 0.01#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0.039
        theta=0.038
        rho=0.02;
        kappa=0.02
        chi=0.02
        sigma=0.02
        tau_b=0.0004  
  
        if (plottatoB==0):# { // Compute the new R0          
            r1=epsilon+zeta+lamda           
            r2=eta+rho            
            r3=theta+mu+kappa            
            r4=nu+chi           
            r5=sigma+tau_b           
            R04=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4 
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4)           
            plottatoB = 1           
            R0 = R04            
                      
    if (t>203): #{ // Social distancing: lockdown, strong effect           
        alpha= 0.25#0.48 0.4218;
        gamma= 0.25#0.38 #0.285;
        beta = 0.25#0.025 #0.0057;
        delta= 0.25#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0.039
        theta=0.038
        rho=0.02;
        kappa=0.02
        chi=0.02
        sigma=0.02
        tau_b=0.0004
        if (plottatoC==0):# { // Compute the new R0          
            r1=epsilon+zeta+lamda           
            r2=eta+rho            
            r3=theta+mu+kappa            
            r4=nu+chi           
            r5=sigma+tau_b           
            R04=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4 
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4)           
            plottatoC = 1           
            R0 = R04  
                        
            
    if (t>230): #{ // Social distancing: lockdown, strong effect           
        alpha= 0.001#0.48 0.4218;
        gamma= 0.001#0.38 #0.285;
        beta = 0.001#0.025 #0.0057;
        delta= 0.001#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0.039
        theta=0.038
        rho=0.9;
        kappa=0.9
        chi=0.9
        sigma=0.9
        tau_b=0.0004
        if (plottatoD==0):# { // Compute the new R0          
            r1=epsilon+zeta+lamda           
            r2=eta+rho            
            r3=theta+mu+kappa            
            r4=nu+chi           
            r5=sigma+tau_b           
            R0D=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4 
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4)           
            plottatoD = 1           
            R0 = R0D            
                        
            
    if (t>231): #{ // Social distancing: lockdown, strong effect           
        alpha= 0.001#0.48 0.4218;
        gamma= 0.001#0.38 #0.285;
        beta = 0.001#0.025 #0.0057;
        delta= 0.001#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0.039
        theta=0.038
        rho=0.035;
        kappa=0.035
        chi=0.035
        sigma=0.035
        tau_b=0.0004
        if (plottatoE==0):# { // Compute the new R0          
            r1=epsilon+zeta+lamda           
            r2=eta+rho            
            r3=theta+mu+kappa            
            r4=nu+chi           
            r5=sigma+tau_b           
            R0E=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4 
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4)           
            plottatoE = 1           
            R0 = R0E                       
                 
     
    if (t>248): #{ // Social distancing: lockdown, strong effect           
        alpha= 0.16#0.48 0.4218;
        gamma= 0.16#0.38 #0.285;
        beta = 0.16#0.025 #0.0057;
        delta= 0.16#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0.039
        theta=0.038
        rho=0.01;
        kappa=0.01
        chi=0.01
        sigma=0.01
        tau_b=0.0004
        if (plottatoF==0):# { // Compute the new R0          
            r1=epsilon+zeta+lamda           
            r2=eta+rho            
            r3=theta+mu+kappa            
            r4=nu+chi           
            r5=sigma+tau_b           
            R0F=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4 
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4)           
            plottatoF = 1           
            R0 = R0F   
            
            
    if (t>280): #{ // Social distancing: lockdown, strong effect           
        alpha= 0.2#0.48 0.4218;
        gamma= 0.2#0.38 #0.285;
        beta = 0.2#0.025 #0.0057;
        delta= 0.2#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0.039
        theta=0.038
        rho=0.0091;
        kappa=0.0091
        chi=0.0091
        sigma=0.0091
        tau_b=0.0004
        if (plottatoG==0):# { // Compute the new R0          
            r1=epsilon+zeta+lamda           
            r2=eta+rho            
            r3=theta+mu+kappa            
            r4=nu+chi           
            r5=sigma+tau_b           
            R0G=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4 
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4)           
            plottatoG = 1           
            R0 = R0G             
            
    if (t>298): #{ // Social distancing: lockdown, strong effect           
        alpha= 0.125#0.48 0.4218;
        gamma= 0.125#0.38 #0.285;
        beta = 0.125#0.025 #0.0057;
        delta= 0.125#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0.039
        theta=0.038
        rho=0.05;
        kappa=0.05
        chi=0.05
        sigma=0.05
        tau_b=0.0004
        if (plottatoH==0):# { // Compute the new R0          
            r1=epsilon+zeta+lamda           
            r2=eta+rho            
            r3=theta+mu+kappa            
            r4=nu+chi           
            r5=sigma+tau_b           
            R0H=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4 
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4)           
            plottatoH = 1           
            R0 = R0H            
            
    if (t>340): #{ // Social distancing: lockdown, strong effect           
        alpha= 0.092#0.48 0.4218;
        gamma= 0.092#0.38 #0.285;
        beta = 0.092#0.025 #0.0057;
        delta= 0.092#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0.039
        theta=0.038
        rho=0.05;
        kappa=0.05
        chi=0.05
        sigma=0.05
        tau_b=0.0004
 
        if (plottatoI==0):# { // Compute the new R0          
            r1=epsilon+zeta+lamda           
            r2=eta+rho            
            r3=theta+mu+kappa            
            r4=nu+chi           
            r5=sigma+tau_b           
            R0I=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4 
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4)           
            plottatoI = 1           
            R0 = R0I
 
    if (t>400): #{ // Social distancing: lockdown, strong effect           
        alpha= 0.09#0.48 0.4218;
        gamma= 0.09#0.38 #0.285;
        beta = 0.09#0.025 #0.0057;
        delta= 0.09#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0.039
        theta=0.038
        rho=0.01;
        kappa=0.01
        chi=0.01
        sigma=0.01
        tau_b=0.0004
        if (plottatoJ==0):# { // Compute the new R0          
            r1=epsilon+zeta+lamda           
            r2=eta+rho            
            r3=theta+mu+kappa            
            r4=nu+chi           
            r5=sigma+tau_b           
            R0J=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4 
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4)           
            plottatoJ = 1           
            R0 = R0J    
    
    if (t>452): #{ // Social distancing: lockdown, strong effect           
        alpha= 0.09#0.48 0.4218;
        gamma= 0.09#0.38 #0.285;
        beta = 0.09#0.025 #0.0057;
        delta= 0.09#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0.039
        theta=0.038
        rho=0.01;
        kappa=0.01
        chi=0.01
        sigma=0.01
        tau_b=0.0004
        
        tau_a   = 0.0001
        phi     = 0.00007#0.0018
        alpha_p = 0.00007#0.0018         
                    
        if (plottatoK==0):# { // Compute the new R0          
            r1=epsilon+zeta+lamda           
            r2=eta+rho            
            r3=theta+mu+kappa            
            r4=nu+chi           
            r5=sigma+tau_b           
            R0K=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4 
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4)           
            plottatoK = 1           
            R0 = R0K  
 
    if (t>457): #{ // Social distancing: lockdown, strong effect           
        alpha= 0.09#0.48 0.4218;
        gamma= 0.09#0.38 #0.285;
        beta = 0.09#0.025 #0.0057;
        delta= 0.09#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0.039
        theta=0.038
        rho=0.3;
        kappa=0.3
        chi=0.3
        sigma=0.3
        tau_b=0.0004
        
        tau_a   = 0.0001
        phi     = 0.00014#0.0018
        alpha_p = 0.00014#0.0018
        if (plottatoL==0):# { // Compute the new R0          
            r1=epsilon+zeta+lamda           
            r2=eta+rho            
            r3=theta+mu+kappa            
            r4=nu+chi           
            r5=sigma+tau_b           
            R0L=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4 
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4)           
            plottatoL = 1           
            R0 = R0L               

    if (t>462): #{ // Social distancing: lockdown, strong effect           
        alpha= 0.06#0.48 0.4218;
        gamma= 0.06#0.38 #0.285;
        beta = 0.06#0.025 #0.0057;
        delta= 0.06#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0.039
        theta=0.038
        rho=0.01;
        kappa=0.01
        chi=0.01
        sigma=0.01
        tau_b=0.0004
        
        tau_a   = 0.0001
        phi     = 0.00014#0.0018
        alpha_p = 0.00014#0.0018
        if (plottatoM==0):# { // Compute the new R0   
            
            r1=epsilon+zeta+lamda           
            r2=eta+rho            
            r3=theta+mu+kappa            
            r4=nu+chi           
            r5=sigma+tau_b           
            R0M=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4 
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4)           
            plottatoM = 1           
            R0 = R0M                                     
            
 
    if (t>475): #{ // Social distancing: lockdown, strong effect           
        alpha= 0.179#0.48 0.4218;
        gamma= 0.179#0.38 #0.285;
        beta = 0.179#0.025 #0.0057;
        delta= 0.179#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0.039
        theta=0.038
        rho=0.01;
        kappa=0.01
        chi=0.01
        sigma=0.01
        tau_b=0.0004
        
        
        tau_a   = 0.0001
        phi     = 0.00014#0.0018
        alpha_p = 0.00014#0.0018
        if (plottatoZ==0):# { // Compute the new R0   
            
            r1=epsilon+zeta+lamda           
            r2=eta+rho            
            r3=theta+mu+kappa            
            r4=nu+chi           
            r5=sigma+tau_b           
            R0Z=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4 
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4)           
            plottatoZ = 1           
            R0 = R0Z  

            
    if (t>490): #{ // Social distancing: lockdown, strong effect           
        alpha= 0.179#0.48 0.4218;
        gamma= 0.169#0.38 #0.285;
        beta = 0.179#0.025 #0.0057;
        delta= 0.179#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0.039
        theta=0.038
        rho=0.01;
        kappa=0.01
        chi=0.01
        sigma=0.01
        tau_b=0.0004
        
        
        tau_a   = 0.0001
        phi     = 0.00007#0.0018
        alpha_p = 0.00007#0.0018
        if (plottatoZ11==0):# { // Compute the new R0   
            
            r1=epsilon+zeta+lamda           
            r2=eta+rho            
            r3=theta+mu+kappa            
            r4=nu+chi           
            r5=sigma+tau_b           
            R0Z11=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4 
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4)           
            plottatoZ11 = 1           
            R0 = R0Z11              
            
            
    if (t>524): #{ // Social distancing: lockdown, strong effect           
        alpha= 0.12#0.48 0.4218;
        gamma= 0.11#0.38 #0.285;
        beta = 0.10#0.025 #0.0057;
        delta= 0.09#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0.039
        theta=0.038
        rho=0.01;
        kappa=0.01
        chi=0.01
        sigma=0.01
        tau_b=0.0004
        
        
        tau_a   = 0.0001
        phi     = 0.00002#0.0018
        alpha_p = 0.00002#0.0018
        if (plottatoZ2==0):# { // Compute the new R0   
            
            r1=epsilon+zeta+lamda           
            r2=eta+rho            
            r3=theta+mu+kappa            
            r4=nu+chi           
            r5=sigma+tau_b           
            R0Z2=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4 
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4)           
            plottatoZ2 = 1           
            R0 = R0Z2
            
            
    if (t>545): #{ // Social distancing: loc0down, strong effect           
        alpha= 0.11#0.48 0.4218;
        gamma= 0.10#0.38 #0.285;
        beta = 0.10#0.025 #0.0057;
        delta= 0.10#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0.039
        theta=0.038
        rho=0.3;
        kappa=0.3
        chi=0.3
        sigma=0.3
        tau_b=0.0009

        tau_a   = 0.0001
        phi     = 0.00004#0.0018
        alpha_p = 0.00004#0.0018        
        
        if (plottatoY==0):# { // Compute the new R0   
            
            r1=epsilon+zeta+lamda           
            r2=eta+rho            
            r3=theta+mu+kappa            
            r4=nu+chi           
            r5=sigma+tau_b           
            R0Y=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4 
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4)           
            plottatoY = 1           
            R0 = R0Y   
            
            
    if (t>547): #{ // Social distancing: lockdown, strong effect           
        alpha= 0.12#0.48 0.4218;
        gamma= 0.12#0.38 #0.285;
        beta = 0.12#0.025 #0.0057;
        delta= 0.12#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0.039
        theta=0.038
        rho=0.06
        kappa=0.06
        chi=0.06
        sigma=0.06
        tau_b=0.0008

        tau_a   = 0.0001
        phi     = 0.00004#0.0018
        alpha_p = 0.00004#0.0018
        if (plottatoX==0):# { // Compute the new R0   
            
            r1=epsilon+zeta+lamda           
            r2=eta+rho            
            r3=theta+mu+kappa            
            r4=nu+chi           
            r5=sigma+tau_b           
            R0X=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4 
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4)           
            plottatoX = 1           
            R0 = R0X               

            
    if (t>572): #{ // Social distancing: lockdown, strong effect           
        alpha= 0.01#0.48 0.4218;
        gamma= 0.01#0.38 #0.285;
        beta = 0.01#0.025 #0.0057;
        delta= 0.01#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0.039
        theta=0.038
        rho=0.01
        kappa=0.01
        chi=0.01
        sigma=0.01
        tau_b=0.0008

        tau_a   = 0.0001
        phi     = 0.00009#0.0018
        alpha_p = 0.00009#0.0018
        if (plottatoX1==0):# { // Compute the new R0   
            
            r1=epsilon+zeta+lamda           
            r2=eta+rho            
            r3=theta+mu+kappa            
            r4=nu+chi           
            r5=sigma+tau_b           
            R0X1=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4 
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4)           
            plottatoX1 = 1           
            R0 = R0X1              
            
    if (t>601): #{ // Social distancing: lockdown, strong effect           
        alpha= 0.1#0.48 0.4218;
        gamma= 0.1#0.38 #0.285;
        beta = 0.1#0.025 #0.0057;
        delta= 0.1#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0.039
        theta=0.038
        rho=0.2
        kappa=0.1
        chi=0.1
        sigma=0.1
        tau_b=0.0008

        tau_a   = 0.0001
        phi     = 0.00009#0.0018
        alpha_p = 0.00009#0.0018
        
        
        if (plottatoV==0):# { // Compute the new R0   
            
            r1=epsilon+zeta+lamda           
            r2=eta+rho            
            r3=theta+mu+kappa            
            r4=nu+chi           
            r5=sigma+tau_b           
            R0V=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4 
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4)           
            plottatoV = 1           
            R0 = R0V      
            
            
    if (t>603): #{ // Social distancing: lockdown, strong effect           
        alpha= 0.19#0.48 0.4218;
        gamma= 0.19#0.38 #0.285;
        beta = 0.19#0.025 #0.0057;
        delta= 0.19#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0.039
        theta=0.038
        rho=0.03
        kappa=0.03
        chi=0.03
        sigma=0.03
        tau_b=0.0008

        tau_a   = 0.0001
        phi     = 0.00009#0.0018
        alpha_p = 0.00009#0.0018
        
        if (plottatoP==0):# { // Compute the new R0          
            r1=epsilon+zeta+lamda           
            r2=eta+rho            
            r3=theta+mu+kappa            
            r4=nu+chi           
            r5=sigma+tau_b          
            R0P=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4 
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4)           
            plottatoP = 1           
            R0 = R0P  
            
    if (t>604): #{ // Social distancing: lockdown, strong effect           
        alpha= 0.19#0.48 0.4218;
        gamma= 0.19#0.38 #0.285;
        beta = 0.19#0.025 #0.0057;
        delta= 0.19#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.2
        eta=0.2
        epsilon=0.039
        theta=0.038
        rho=0.03
        kappa=0.03
        chi=0.03
        sigma=0.03
        tau_b=0.0004

        tau_a   = 0.0001
        phi     = 0.00009#0.0018
        alpha_p = 0.00009#0.0018
        
        if (plottatoP1==0):# { // Compute the new R0          
            r1=epsilon+zeta+lamda           
            r2=eta+rho            
            r3=theta+mu+kappa            
            r4=nu+chi           
            r5=sigma+tau_b          
            R0P1=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4 
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4)           
            plottatoP1 = 1           
            R0 = R0P1  
                        
            
    if (t>669):# // Social distancing: lockdown, strong effect           

        alpha= 0.08#0.48 0.4218;
        gamma= 0.08#0.38 #0.285;
        beta = 0.08#0.025 #0.0057;
        delta= 0.08#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.3
        eta=0.3
        epsilon=0.039
        theta=0.038
        rho=0.04
        kappa=0.04
        chi=0.04
        sigma=0.04
        tau_b=0.0004

        tau_a   = 0.0001
        phi     = 0.0001#0.0018
        alpha_p = 0.0001#0.0018
        if (plottatoQ==0):# { // Compute the new R0          
            r1=epsilon+zeta+lamda           
            r2=eta+rho            
            r3=theta+mu+kappa            
            r4=nu+chi           
            r5=sigma+tau_b           
            R0Q=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4 
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4)           
            plottatoQ = 1           
            R0 = R0Q             
                                    
    if (t>690):# // Social distancing: lockdown, strong effect           

        alpha= 0.1#0.48 0.4218;
        gamma= 0.1#0.38 #0.285;
        beta = 0.1#0.025 #0.0057;
        delta= 0.1#0.025 #0.0057;

        lamda=0.0001 #0.00 #0.08;

        mu=0.2
        nu=0.3
        zeta=0.3
        eta=0.3
        epsilon=0.039
        theta=0.038
        rho=0.01
        kappa=0.01
        chi=0.01
        sigma=0.01
        tau_b=0.0004

        tau_a   = 0.0001
        phi     = 0.0001#0.0018
        alpha_p = 0.0001#0.0018
        if (plottatoQ1==0):# { // Compute the new R0          
            r1=epsilon+zeta+lamda           
            r2=eta+rho            
            r3=theta+mu+kappa            
            r4=nu+chi           
            r5=sigma+tau_b           
            R0Q1=(alpha*r2*r3*r4+epsilon*beta*r3*r4+gamma*zeta*r2*r4 
            +delta*eta*epsilon*r3+delta*zeta*theta*r2)/(r1*r2*r3*r4)           
            plottatoQ1 = 1           
            R0 = R0Q1             
                               


    par= alpha,beta,delta, gamma,epsilon,zeta,lamda,eta,rho,theta,mu,kappa,nu,chi,sigma,tau_b,tau_a,phi,alpha_p    
            
    return R0,par;

# %%
data_time=data['daily']

data_infected=data['confirmed_cases']

data_recovered=data['Recovered']

data_dead=data['total_deaths']


data_active=data['active_cases']

#one_dose=data['one dose of vacination']
#print(len(one_dose))

Goodness=data['Goodnessfit']


N=2.175e8
Dactifs=[]
Ddeads=[]
Drecovereds=[]
Dinfecteds=[]

for i in data_active:
    Dactifs.append(i/N)
    
for i in data_infected:
    Dinfecteds.append(i/N)    

for i in data_dead:
    Ddeads.append(i/N) 

for i in data_recovered:
    Drecovereds.append(i/N)

# %%
#initial condition

par=0.57,0.0114,0.0114,0.456,0.171,0.1254,0.0342,0.1254, 0.0342, 0.3705,0.0171,0.0171,0.0274,0.0171,0.0171, 0.1605,0.00,0.00,0.00
R0=[]
parm=[]
t1=[]
for i in range(len(data_time)):
   # print(rzero(t,par))
    R0.append( rzero(i,par)[0])
    parm.append( rzero(i,par)[1])
    t1.append(i)
#print(R0)
#print(parm)
t= np.array(t1, dtype=float)
#print(t)
#t2 = np.linspace(0, 85, 86)
parm[0]
par1= np.array(parm, dtype=float)
#print(par1)
#par1[151][0]

alpha1=[]
beta1=[]
delta1=[]
gamma1=[]
epsilon1=[]
zeta1=[]
lamda1=[]
eta1=[]
rho1=[]
theta1=[]
mu1=[]
kappa1=[]
nu1=[]
chi1=[]
sigma1=[]
tau_b1=[]
tau_a1=[]
phi1=[]
alpha_p1=[]



for i in range(len(data_time)):
    alpha1.append(par1[i][0])
    beta1.append(par1[i][1])
    delta1.append(par1[i][2])
    gamma1.append(par1[i][3])
    epsilon1.append(par1[i][4])
    zeta1.append(par1[i][5])
    lamda1.append(par1[i][6])
    eta1.append(par1[i][7])
    rho1.append(par1[i][8])
    theta1.append(par1[i][9])
    mu1.append(par1[i][10])
    kappa1.append(par1[i][11])
    nu1.append(par1[i][12])
    chi1.append(par1[i][13])
    sigma1.append(par1[i][14])
    tau_b1.append(par1[i][15])
    tau_a1.append(par1[i][16])
    phi1.append(par1[i][17])
    alpha_p1.append(par1[i][18] )

# %%
alpha2=np.array(alpha1)
beta2=np.array(beta1)
delta2=np.array(delta1)
gamma2=np.array(gamma1)
epsilon2=np.array(epsilon1)
zeta2=np.array(zeta1)
lamda2=np.array(lamda1)
eta2=np.array(eta1)
rho2=np.array(rho1)
theta2=np.array(theta1)
mu2=np.array(mu1)
kappa2=np.array(kappa1)
nu2=np.array(nu1)
chi2=np.array(chi1)
sigma2=np.array(sigma1)
tau_b2=np.array(tau_b1)
tau_a2=np.array(tau_a1)
phi2=np.array(phi1)
alpha_p2=np.array(alpha_p1)

# %%
dR0st=R0*(1/np.sqrt(data_active)+1/np.sqrt(data_recovered))

# %%
for i in range(len(data_time)):
    if(data_active[i]>0 and data_recovered[i]>0):
        dR0st[i]=R0[i]*(1/np.sqrt(data_active[i])+1/np.sqrt(data_recovered[i]))
    
    elif ( data_recovered[i]==0 and data_active[i]>0):
        dR0st[i]=R0[i]*(1/np.sqrt(data_active[i]))

    elif ( data_recovered[i]>0 and data_active[i]==0):
        dR0st[i]=R0[i]*(1/np.sqrt(data_recovered[i]))
    elif ( data_recovered[i]==0 and data_active[i]==0):
        dR0st[i]=0

# %%
alpha=0.7
# Plotting The reproduction number
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 20
fig_size[1] = 10
plt.rcParams["figure.figsize"] = fig_size
fig = plt.figure()
ax = plt.subplot(111)
#t = np.linspace(0, 67, 67)

plt.plot(t,R0,'black', label='R0(t)=reproduction number',linewidth=4) # plotting t, c separately 
plt.fill_between(t ,R0-dR0st,R0+dR0st,color='r',alpha=alpha,label='Statistical Uncertainty')
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.title('Basic Reproduction Number (R0)_Nigeria',fontsize=20)
plt.xlabel("Time in days",fontsize=20)
plt.ylabel("Basic Reproduction Number (R0)_Nigeria",fontsize=20)
ax.legend(loc=2, prop={'size': 20})
#plt.xscale("log")
#plt.yscale("log")
plt.grid(True)
plt.savefig("Statistical Uncertainty (R0)_Nigeria", dpi=300, bbox_inches='tight')
plt.show()

# %%
# Plotting The reproduction number
fig = plt.figure()
ax = plt.subplot(111)
#t = np.linspace(0, 67, 67)

plt.plot(t,R0,'black', label='R0(t)=reproduction number',linewidth=2) # plotting t, c separately 

plt.errorbar(data_time ,R0,dR0st,fmt='o',color='r',label='Infected',elinewidth=4,capsize=5)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.title('Nigeria Basic Reproduction Number (R0)',fontsize=20)
plt.xlabel("Time in days",fontsize=20)
plt.ylabel("Basic Reproduction Number (R0)",fontsize=20)
ax.legend(loc=2, prop={'size': 20})
#plt.xscale("log")
#plt.yscale("log")
plt.grid(True)

plt.show()

# %%
alpha=interp1d(t,alpha2,bounds_error=False, fill_value="extrapolate")
beta=interp1d(t,beta2,bounds_error=False, fill_value="extrapolate")
delta=interp1d(t,delta2,bounds_error=False, fill_value="extrapolate")
gamma=interp1d(t,gamma2,bounds_error=False, fill_value="extrapolate")
epsilon=interp1d(t,epsilon2,bounds_error=False, fill_value="extrapolate")
zeta=interp1d(t,zeta2,bounds_error=False, fill_value="extrapolate")
lamda=interp1d(t,lamda2,bounds_error=False, fill_value="extrapolate")
eta=interp1d(t,eta2,bounds_error=False, fill_value="extrapolate")
rho=interp1d(t,rho2,bounds_error=False, fill_value="extrapolate")
theta=interp1d(t,theta2,bounds_error=False, fill_value="extrapolate")
mu=interp1d(t,mu2,bounds_error=False, fill_value="extrapolate")
kappa=interp1d(t,kappa2,bounds_error=False, fill_value="extrapolate")
nu=interp1d(t,nu2,bounds_error=False, fill_value="extrapolate")
chi=interp1d(t,chi2,bounds_error=False, fill_value="extrapolate")
sigma=interp1d(t,sigma2,bounds_error=False, fill_value="extrapolate")
tau_b=interp1d(t,tau_b2,bounds_error=False, fill_value="extrapolate")
tau_a=interp1d(t,tau_a2,bounds_error=False, fill_value="extrapolate")
phi=interp1d(t,phi2,bounds_error=False, fill_value="extrapolate")
alpha_p=interp1d(t,alpha_p2,bounds_error=False, fill_value="extrapolate")

# %%
def SIDARTHEV_model(y, t,N, alpha,beta,delta, gamma,epsilon,zeta,lamda,eta,rho,theta,mu,kappa,nu,chi,sigma,tau_b,tau_a,phi,alpha_p):
    S = y[0]   #Succeptible
    I = y[1]   #Infected asymptomatic undetected
    D = y[2]   #Diagnosed asymptomatic infected detected
    A = y[3]   #Ailing symptomatic infected undetected
    R = y[4]   # Recognised symptomatic infected detected
    T = y[5]   #Treathened accutely symptomatic infected detected
    H = y[6]   # Healed
    E = y[7]   # Extinct (deads)
    V = y[8]
    U = y[9]
    return [-S*(alpha(t)*I + beta(t)*D +gamma(t)*A + delta(t)*R) - phi(t)*S,
            S*(alpha(t)*I + beta(t)*D +gamma(t)*A + delta(t)*R) + alpha_p(t)*I*V-(epsilon(t)+lamda(t)+zeta(t))*I,
            epsilon(t)*I-(eta(t)+rho(t))*D,
            zeta(t)*I-(theta(t)+mu(t)+kappa(t))*A,
            eta(t)*D +theta(t)*A-(tau_a(t) + nu(t) + chi(t))*R,
            mu(t)*A+nu(t)*R-(sigma(t)+tau_b(t))*T,
            lamda(t)*I +rho(t)*D + kappa(t)*A  + sigma(t)*T +chi(t)*R,
            tau_a(t)*R + tau_b(t)*T,
            - alpha_p(t)*I*V + phi(t)*S,
            lamda(t)*I]

# %%
N=2.17e8

#itemp[0] = 0.0/population;
#   dtemp[0] = 1.0/population;
 #  atemp[0] = 0.25/population;
  # rtemp[0] = 1.0/population;
 #  ttemp[0] = 0.0;
 #  htemp[0] = 0.0;
 #  etemp[0] = 0.0;
#   stemp[0] = 1.0-itemp[0]-dtemp[0]-atemp[0]-rtemp[0]-ttemp[0]-htemp[0]-etemp[0];


I0=  0.0/N#20./N
D0=  1/N     #9./N
A0=  0.25/N       #1./N
R0= 1/N            #2./N
T0=0.00
H0=0.00
E0=0.00
V0=0.00
S0=1-I0-D0-A0-R0-T0-H0-E0-V0
U0=0.00
y0 = S0,I0,D0,A0,R0,T0,H0,E0,V0,U0

#time (days)
#t = np.linspace(0, 67, 67)

# Integrate the SIR equations over the time grid, t.
ret = odeint(SIDARTHEV_model, y0, t, args=(N, alpha,beta,delta, gamma,epsilon,zeta,lamda,eta,rho,theta,mu,kappa,nu,chi,sigma,tau_b,tau_a,alpha_p,phi))
S,I,D,A,R,T,H,E,V,U= ret.T

# %%
actif_sidarthe=[]
t=[]
for i in range(len(data_time)):
    t.append(i)
    actif_sidarthe.append(A[i]+T[i]+R[i])

# %%
Infected_sidarthe=[]
t=[]
for i in range(len(data_time)):
    t.append(i)
    Infected_sidarthe.append(A[i]+T[i]+R[i]+H[i]+E[i])

# %%
fig = plt.figure()
ax = plt.subplot(111)

plt.yscale('log')
#plt.plot(t, S, label='S=Succeptible',linewidth=4) # plotting t, a separately
plt.plot(t, I, 'r',label='I=Infected',linewidth=4) # plotting t, a separately 
plt.plot(t, D,label='D=Diagnosed',linewidth=4) # plotting t, b separately 
plt.plot(t, A,label='A=Ailing',linewidth=4) # plotting t, c separately 
plt.plot(t, R, label='R=Recognized',linewidth=4) # plotting t, a separately 
plt.plot(t, T, label='T=Treathened',linewidth=4) # plotting t, a separately 
plt.plot(t, H,label='H=healed',linewidth=4) # plotting t, b separately 
plt.plot(t, E,label='E=Extinct',linewidth=4) # plotting t, c separately 
plt.plot(t, actif_sidarthe,label='Actif_S=actif_sidarthe',linewidth=4) # plotting t, c separately 
plt.plot(t, Infected_sidarthe,label='Infected_S=Infected_sidarthee',linewidth=4)
         
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
#plt.title('SIDARTHE_model based on covid19 Mozambican data with varied R0',fontsize=30)
plt.xlabel("time(days)",fontsize=20)
ax.legend(loc=2, prop={'size': 15})
#plt.xscale("log")
#plt.yscale("log")
plt.show()
fig.savefig('SIDARTHE_model_variousR024052020.pdf')

# %%
Unaffected=lamda2*I
#print(len(I))

N=2.17e8
dR0syst=R0*((U)/(H))*N


DR0= np.sqrt((dR0st*dR0st)+(dR0syst*dR0syst))

par=0.57,0.0114,0.0114,0.456,0.171,0.1254,0.0342,0.1254, 0.0342, 0.3705,0.0171,0.0171,0.0274,0.0171,0.0171, 0.1605,0.00,0.00,0.00
R0=[]
parm=[]
t1=[]
for i in range(len(data_time)):
   # print(rzero(t,par))
    R0.append( rzero(i,par)[0])
    parm.append( rzero(i,par)[1])
    t1.append(i)
#print(R0)
#print(parm)
t= np.array(t1, dtype=float)
#print(t)
#t2 = np.linspace(0, 85, 86)
parm[0]
par1= np.array(parm, dtype=float)






plt.rcParams["font.weight"] #= \"bold\"
plt.rcParams["axes.labelweight"] #= \"bold\"
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 20
fig_size[1] = 10
plt.rcParams["figure.figsize"] = fig_size
# Plotting The reproduction number


fig = plt.figure()
ax = plt.subplot(111)
#t = np.linspace(0, 67, 67)
plt.plot(t,R0,'r', label='R0(t)=reproduction number',linewidth=2) # plotting t, c separately 
#plt.plot(t,dR0syst,'r', label='R0(t)=reproduction number',linewidth=2)
#plt.errorbar(t ,R0,dR0syst, fmt='o',color='r',label='Systematic Uncertainty',elinewidth=4,capsize=5)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.title(' Basic Reproduction Number (R0) ',fontsize=20)
plt.xlabel("Time in days",fontsize=20)
plt.ylabel("Basic Reproduction Number (R0)",fontsize=20)
ax.legend(loc=2, prop={'size': 20})
#plt.xscale("log")
#plt.yscale("log")
plt.grid()
#plt.show()
plt.savefig("Nigeria_R(0).pdf")
# Out:
# /tmp/ipykernel_26937/2384147449.py:5: RuntimeWarning: invalid value encountered in true_divide
#   dR0syst=R0*((U)/(H))*N

# %%
fig = plt.figure(figsize=(13,10))
ax = plt.subplot(111)
#t = np.linspace(0, 67, 67)
#plt.plot(data_time ,Unaffected,'black', label='Unaffected and Healed',linewidth=2)
plt.plot(data_time ,U,'black', label='Unaffected',linewidth=2)
plt.plot(data_time ,H,'b', label='Healed',linewidth=2)
# plotting t, c separately 
#plt.plo
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
#plt.title('Unaffected_Mozambique',fontsize=20)
plt.xlabel("Time (days)",fontsize=20)
ax.legend(loc=2, prop={'size': 20})
plt.ylabel("Fractions of Population",fontsize=20)
plt.yscale("log")
plt.ylim(0, 10**-2)
plt.xlim(0, 750)
#plt.grid()
#plt.grid()
plt.savefig("Unaffected and Healed_Nigeria", dpi=300, bbox_inches='tight')
# Out:
# /tmp/ipykernel_26937/1139576600.py:16: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.ylim(0, 10**-2)

# %%
fig = plt.figure()
ax = plt.subplot(111)
#t = np.linspace(0, 67, 67)
plt.plot(data_time ,U/H,'black', label='Unaffected/Healed',linewidth=2)

# plotting t, c separately 
#plt.plo
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.title('Ratio_Nigeria ',fontsize=20)
plt.xlabel("Time in Days",fontsize=20)
ax.legend(loc=2, prop={'size': 20})

#plt.yscale("log")
plt.grid()
plt.savefig("Ratio_Nigeria", dpi=300, bbox_inches='tight')
#plt.show()
# Out:
# /tmp/ipykernel_26937/4135205739.py:4: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(data_time ,U/H,'black', label='Unaffected/Healed',linewidth=2)

# %%
one_dose= data['one dose of vacination']
fully_vaccine= data['fully_vaccinated']
total_vaccine= data['total_vaccinations']

Done_dose= data['Fration_one dose of vacination']
Dfully_vaccine= data['Fration_fully_vaccinated']
Dtotal_vaccine= data['Fration_total_vaccinations']

# %%
#To see how to plot with error bars, go here: https://www.youtube.com/watch?v=xhizVO9SPjU
error_infectedf=((np.sqrt((data_infected)))/N)
error_dead=((np.sqrt((data_dead)))/N)
error_actif=((np.sqrt((data_active)))/N)
error_recovered=((np.sqrt((data_recovered)))/N)
error_one_dose=((np.sqrt((one_dose)))/N)
error_fully_vaccine=((np.sqrt((fully_vaccine)))/N)
error_total_vaccine=((np.sqrt((total_vaccine)))/N)

# %%
t1=data_time[453:-1]

# %%
fig = plt.figure()
ax = plt.subplot(111)


#plt.semilogy(data_time ,Dinfecteds,'o',label='Infecteds',linewidth=6,color='g')
#plt.semilogy(data_time ,Dactifs,'o',label='Actifs',linewidth=6,color='b')
#plt.semilogy(data_time ,Drecovereds,'o',label='Recovered',linewidth=6,color='c')
#plt.semilogy(data_time ,Ddeads,'o',label='Dead',linewidth=6,color='gray')

plt.errorbar(data_time ,Dinfecteds,yerr=error_infectedf,fmt='o',color='g',label='Infected',elinewidth=2,capsize=2)
plt.errorbar(data_time ,Dactifs,yerr=error_actif,fmt='o', color='b',label='Actif',elinewidth=2,capsize=2)
plt.errorbar(data_time ,Drecovereds,yerr=error_recovered,fmt='o', color='c',label='Recovered',elinewidth=2,capsize=2)

#plt.errorbar(data_time ,Done_dose,yerr=error_one_dose,fmt='o', color='black',label='one dose',elinewidth=4,capsize=5)
plt.errorbar(data_time ,Dfully_vaccine,yerr=error_fully_vaccine,fmt='o', color='y',label='fully_vaccine',elinewidth=4,capsize=5)
plt.errorbar(data_time ,Dtotal_vaccine,yerr=error_total_vaccine,fmt='o', color='r',label='total_vaccine',elinewidth=4,capsize=5)

plt.plot(t1, V[t1], 'y',label='Vaccination',linewidth=2)
             
             
             
plt.errorbar(data_time ,Ddeads,yerr=error_dead,fmt='o', color='gray',label='Dead',elinewidth=4,capsize=5)
plt.plot(t, E,'gray',label='E=Extinct',linewidth=2) # plotting t, c separately 
plt.plot(t, actif_sidarthe,'b',label='Actif_S=actif_sidarthe',linewidth=2) # plotting t, c separately
plt.plot(t, H,'c',label='H=healed',linewidth=2) # plotting t, b separately 
plt.plot(t, Infected_sidarthe, 'g',label='Infected_sidarthe',linewidth=2)

plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.xlabel("Time in days",fontsize=20)
plt.ylabel("Fractions of Population",fontsize=20)

plt.title('Modeling of Covid-19, Nigeria Data  ',fontsize=20)
plt.legend()
ax.legend(loc=2, prop={'size': 15})
plt.yscale('log')
plt.ylim(3.5*10**-9, 10**0)
plt.grid(True)
# Out:
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:44: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:40: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:44: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:40: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)

# %%
infect=((np.sqrt((data_infected)))/N)
dea=((np.sqrt((data_dead)))/N)
act=((np.sqrt((data_active)))/N)
recov=((np.sqrt((data_recovered)))/N)

uncert_infectedf=np.divide(infect, Infected_sidarthe)
uncert_actif=np.divide(act, actif_sidarthe)
uncert_dead=np.divide(dea, E)
uncert_recovered=np.divide(recov, H)

# %%
fig = plt.figure(figsize=(15,10))

alpha=0.7
plt.subplot(221)

out=np.divide(Dinfecteds, Infected_sidarthe)
#print('\nOutput arry: \n',out)
plt.plot(data_time,out,'g',linewidth=2)
plt.plot(data_time,Goodness,'g',linewidth=4)
plt.fill_between(data_time ,out-uncert_infectedf,out+uncert_infectedf,color='g',alpha=alpha)

plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
#plt.xlabel("time (days)",fontsize=20)
plt.ylabel("Data/Model (Confirmed Cases)",fontsize=15)
#plt.title('Goodness of Fit (Nigeria) ',fontsize=20)
plt.legend()
#plt.grid(True)
plt.ylim(0,1.95)

plt.subplot(222)
out1=np.divide(Dactifs, actif_sidarthe)
#print('\nOutput arry: \n',out1)
plt.plot(data_time,out1, 'b',linewidth=2)
plt.plot(data_time,Goodness,'b',linewidth=4)
plt.fill_between(data_time ,out1-uncert_actif,out1+uncert_actif,color='b',alpha=alpha)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
#plt.xlabel("time (days)",fontsize=20)
plt.ylabel("Data/Model (Active Cases)",fontsize=15)
#plt.title('Goodness of Fit (Nigeria) ',fontsize=20)
plt.legend()
#plt.grid(True)
plt.ylim(0,1.95)


plt.subplot(223)
out2=np.divide(Ddeads, E)
#print('\nOutput arry: \n',out2)
plt.plot(data_time,out2, 'gray',linewidth=2)
plt.plot(data_time,Goodness, 'gray',linewidth=4)
plt.fill_between(data_time ,out2-uncert_dead,out2+uncert_dead,color='gray',alpha=alpha)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.xlabel("Time (days)",fontsize=20)
plt.ylabel('Data/Model (Extinct)',fontsize=15)
#plt.title('Goodness of Fittings ',fontsize=20)
plt.legend()
#plt.grid(True)
plt.ylim(0,1.95)


plt.subplot(224)
out3=np.divide(Drecovereds, H)
#print('\nOutput arry: \n',out3)
plt.plot(data_time,out3, 'c',linewidth=2)
plt.plot(data_time,Goodness, 'c',linewidth=4)
plt.fill_between(data_time ,out3-uncert_recovered,out3+uncert_recovered,color='c',alpha=alpha)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.xlabel("Time (days)",fontsize=20)
plt.ylabel("Data/Model (Healed)",fontsize=15)
#plt.title('Goodness of Fittings ',fontsize=20)
plt.legend()
#plt.grid(True)
plt.ylim(0,1.95)

plt.subplots_adjust(hspace=.0)








plt.savefig("Goodness of fitting' (R0) Nigeria", dpi=300, bbox_inches='tight')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /tmp/ipykernel_26937/2469985154.py:38: RuntimeWarning: invalid value encountered in true_divide
#   out2=np.divide(Ddeads, E)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /tmp/ipykernel_26937/2469985154.py:54: RuntimeWarning: invalid value encountered in true_divide
#   out3=np.divide(Drecovereds, H)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
t2=data_time[454:-1]

# %%
dosage=((np.sqrt((data['fully_vaccinated'])))/N)
uncert_dosage=(np.divide(dosage, V))/N

# %%
out5=np.divide(data['Fration_fully_vaccinated'], V)

# %%
fig = plt.figure(figsize=(15,15))
alpha=0.7


out5=np.divide(data['Fration_fully_vaccinated'], V)
#print('\nOutput arry: \n',out)
#plt.plot(data_time,out,'g',linewidth=2)
s = np.random.rand(*t2.shape) * 800 + 500
plt.plot(data_time,data['Goodnessfit'],'k.', markersize=10,label="Goodness of fitting",linewidth=4)
plt.plot(t2,out5[t2],'y.',markersize=10,label='Fully Vaccinated')
#plt.fill_between(data_time ,out5-uncert_dosage,out5+uncert_dosage,color='y',alpha=alpha)
#plt.fill_between(t5 ,out5[t5]-uncert_dosage[t5],out5[t5]+uncert_dosage[t5],color='y',alpha=alpha)
#plt.errorbar(data_time ,out,yerr=uncert_dosage,fmt='o', color='g',label='Dead',elinewidth=4,capsize=10)

plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.xlabel("Time (days)",fontsize=20)
plt.ylabel("Data/Model (Fully Vaccinated)",fontsize=20)
#plt.title('Goodness For Totaly Vaccinated ',fontsize=30)
plt.legend()
#plt.grid(True)
plt.ylim(0,2)
plt.xlim(450,724)
# Out:
# (450.0, 724.0)

# %%
t1=data_time[453:-1]
t2=data_time[353:-1]

# %%
gaps1_starts = 154
gaps1_ends = 158

gaps2_starts = 202
gaps2_ends = 230

gaps3_starts = 232
gaps3_ends = 460

gaps4_ends = 546
gaps5_ends = 601
gaps6_ends = 603
gaps7_ends = 669

# %%
fig = plt.figure(figsize=(15,15))
gs=gridspec.GridSpec(2,1, height_ratios=[2,1])
ax0=plt.subplot(gs[0])
ax0.set_yscale('log')

alpha=0.7
#plt.errorbar(data_time ,Dinfecteds,yerr=error_infectedf,fmt='o',color='g',label='Infected',elinewidth=4,capsize=5)
plt.fill_between(data_time ,Dinfecteds-error_infectedf,Dinfecteds+error_infectedf,color='g',alpha=alpha,label='Total Cases (Data)',linewidth=2)
#plt.fill_between(data_time ,Dactifs-error_actif,Dactifs+error_actif,color='b',alpha=alpha,label='Active Cases (Data)',linewidth=2)
plt.fill_between(data_time ,Drecovereds-error_recovered,Drecovereds+error_recovered,color='c',alpha=alpha,label='Healed (Data)',linewidth=2)
plt.fill_between(data_time ,Ddeads-error_dead,Ddeads+error_dead,color='gray',alpha=alpha,label='Extinct (Data)',linewidth=2)
plt.plot(t1 ,Dfully_vaccine[t1],'y>',label='Fully Vaccinated(Data)',linewidth=2)



plt.fill_between(t[:gaps1_starts+1], Dactifs[:gaps1_starts+1]-error_actif[:gaps1_starts+1], 
                 Dactifs[:gaps1_starts+1]+error_actif[:gaps1_starts+1],
                 color='b',alpha=alpha,label='Active cases(Data)',linewidth=2)


plt.fill_between(t[gaps1_ends+1:gaps2_starts], Dactifs[gaps1_ends+1:gaps2_starts]-error_actif[gaps1_ends+1:gaps2_starts], 
                 Dactifs[gaps1_ends+1:gaps2_starts]+error_actif[gaps1_ends+1:gaps2_starts],
                 color='b',alpha=alpha,linewidth=2)

    
plt.fill_between(t[gaps2_starts+2:gaps2_ends+1], Dactifs[gaps2_starts+2:gaps2_ends+1]-error_actif[gaps2_starts+2:gaps2_ends+1], 
                 Dactifs[gaps2_starts+2:gaps2_ends+1]+error_actif[gaps2_starts+2:gaps2_ends+1],
                 color='b',alpha=alpha,linewidth=2)


plt.fill_between(t[gaps2_ends+2:gaps3_ends+1], Dactifs[gaps2_ends+2:gaps3_ends+1]-error_actif[gaps2_ends+2:gaps3_ends+1], 
                 Dactifs[gaps2_ends+2:gaps3_ends+1]+error_actif[gaps2_ends+2:gaps3_ends+1],
                 color='b',alpha=alpha,linewidth=2)


plt.fill_between(t[gaps3_ends+2:gaps4_ends+1], Dactifs[gaps3_ends+2:gaps4_ends+1]-error_actif[gaps3_ends+2:gaps4_ends+1], 
                 Dactifs[gaps3_ends+2:gaps4_ends+1]+error_actif[gaps3_ends+2:gaps4_ends+1],
                 color='b',alpha=alpha,linewidth=2)

plt.fill_between(t[gaps4_ends+2:gaps5_ends+1], Dactifs[gaps4_ends+2:gaps5_ends+1]-error_actif[gaps4_ends+2:gaps5_ends+1], 
                 Dactifs[gaps4_ends+2:gaps5_ends+1]+error_actif[gaps4_ends+2:gaps5_ends+1],
                 color='b',alpha=alpha,linewidth=2)

plt.fill_between(t[gaps6_ends+5:], Dactifs[gaps6_ends+5:]-error_actif[gaps6_ends+5:], 
                 Dactifs[gaps6_ends+5:]+error_actif[gaps6_ends+5:],
                 color='b',alpha=alpha,linewidth=2)

plt.plot(t[:gaps1_starts+1], actif_sidarthe[:gaps1_starts+1],'b',label='Active (Model)',linewidth=4) # plotting t, c separately
plt.plot(t[gaps1_ends+1:gaps2_starts], actif_sidarthe[gaps1_ends+1:gaps2_starts],'b',linewidth=4)
plt.plot(t[gaps2_starts+2:gaps2_ends+1], actif_sidarthe[gaps2_starts+2:gaps2_ends+1],'b',linewidth=4)
plt.plot(t[gaps2_ends+2:gaps3_ends+1], actif_sidarthe[gaps2_ends+2:gaps3_ends+1],'b',linewidth=4)
plt.plot(t[gaps3_ends+2:gaps4_ends+1], actif_sidarthe[gaps3_ends+2:gaps4_ends+1],'b',linewidth=4)
plt.plot(t[gaps4_ends+2:gaps5_ends+1], actif_sidarthe[gaps4_ends+2:gaps5_ends+1],'b',linewidth=4)
plt.plot(t[gaps6_ends+5:], actif_sidarthe[gaps6_ends+5:],'b',linewidth=4)



plt.plot(t, E,'gray',label='Extinct (Model)',linewidth=4) # plotting t, c separately 
#plt.plot(t, actif_sidarthe,'b',label='Active Cases (Model)',linewidth=4) # plotting t, c separately 
plt.plot(t, H,'c',label='Healed (Model)',linewidth=4) # plotting t, b separately
plt.plot(t, Infected_sidarthe, 'g',label='Total Cases (Model)',linewidth=4)
plt.plot(t1, V[t1], 'y',label='Fully Vaccinated (Model)', linewidth=4)


plt.xticks(fontsize=0)
plt.yticks(fontsize=16)
#plt.xlabel("Time in days",fontsize=20)
plt.ylabel("Fractions of Population",fontsize=20)

plt.title('Modeling of COVID-19 (Nigeria) ',fontsize=20)

#ax.legend(loc=2, prop={'size': 17})


plt.yscale('log')
plt.ylim(3.5*10**-9, 10**0)
#plt.grid(True)

plt.legend(loc='upper left',prop={'size':14})
plt.savefig("Modeling of Covid-19, Nigeria", dpi=300, bbox_inches='tight')
plt.legend(frameon=False, fontsize=15)

plt.axvline(373, ymax=1.0, c='b')
plt.text(373, 2.5e-1,"AstraZeneca",fontsize=14)

plt.axvline(522, ymax=0.95, c='b')
plt.text(522, 2.5e-1,"Moderna",fontsize=14)

plt.axvline(533, ymax=0.90, c='b')
plt.text(533, 1.5e-1,"Johnson & Johnson",fontsize=14)

plt.axvline(596, ymax=0.85, c='b')
plt.text(596, 0.5e-1,"Pfizer",fontsize=14)


ax1=plt.subplot(gs[1], sharex=ax0)



alpha=0.7
# Plotting The reproduction number
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 20
fig_size[1] = 10
plt.rcParams["figure.figsize"] = fig_size


#t = np.linspace(0, 67, 67)

plt.plot(t,R0,'black', label='Basic reproduction number ($R_{0}$)',linewidth=4) # plotting t, c separately 
plt.fill_between(t ,R0-DR0,R0+DR0,color='r',alpha=alpha,label='Total uncertainty')

plt.plot(t,np.ones_like(R0),color='y',label='Reference line for $R_0$=1',linewidth=4)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

plt.xlabel("Time (days)",fontsize=20)
plt.ylabel("$R_0$",fontsize=20)
plt.legend(loc='upper right',prop={'size':14})
plt.axvline(373, ymax=1.0, c='b')
#plt.xscale("log")
#plt.yscale("log")
#plt.grid(True)
plt.xlim(0,730)
plt.subplots_adjust(hspace=.0)



#plt.legend(frameon=False, fontsize=15)
plt.savefig("Modeling of Covid-19,Nigeria_updated", dpi=300, bbox_inches='tight')

# %%
data_active=pd.Series(data_active)
data_time=pd.Series(data_time)
data_fullyvac=data['fully_vaccinated']
#data_time_vac=dados['Days1']
R0=pd.Series(R0)






# CODE A
# First wave
wave_onset_b = [0]
# Find on the active plots the intervals which contain a minimum
onset_in_intervals = [[225, 275], [455, 495], [625, 660]]
# Create a list of the onset days
wave_onset_b.extend([val[1] -1 - int(data_active[val[0]: val[1]].iloc[-1:0:-1].argmin()) for val in onset_in_intervals])
print("Onset days:", wave_onset_b)
print("BACWARD RESULTS")
print("Corresponding fully vaccinated cases :\n",data_fullyvac.fillna(method='ffill')[wave_onset_b])
print("Corresponding active cases :\n",data_active[wave_onset_b])
print("Corresponding days :\n", data_time[wave_onset_b])
print("Ro details \n", type(R0), R0.shape, "\n R0 values\n", R0[wave_onset_b])
print("Total population :", N)
herd_b = N *( 1 - 1/R0[wave_onset_b])
print("Must be vaccinated at the wave onset: \n", herd_b)
# Out:
# Onset days: [0, 249, 490, 638]
# BACWARD RESULTS
# Corresponding fully vaccinated cases :
#  0            NaN
# 249          NaN
# 490    1155810.0
# 638    3516215.0
# Name: fully_vaccinated, dtype: float64
# Corresponding active cases :
#  0         1
# 249    2388
# 490    1242
# 638    3765
# Name: active_cases, dtype: int64
# Corresponding days :
#  0        0
# 249    249
# 490    490
# 638    638
# Name: daily, dtype: int64
# Ro details
#  <class 'pandas.core.series.Series'> (724,)
#  R0 values
#  0      0.030881
# 249    1.479439
# 490    1.655123
# 638    1.672361
# dtype: float64
# Total population : 217000000.0
# Must be vaccinated at the wave onset:
#  0     -6.810010e+09
# 249    7.032280e+07
# 490    8.589189e+07
# 638    8.724335e+07
# dtype: float64

# %%
fig = plt.figure(figsize=(15,10))

alpha=0.7
plt.subplot(331)

out=np.divide(Dinfecteds, Infected_sidarthe)
plt.plot(data_time,out,'g',label='Confirmed Cases',linewidth=2)
plt.plot(data_time,Goodness,'g',linewidth=4)
plt.fill_between(data_time ,out-uncert_infectedf,out+uncert_infectedf,color='g',alpha=alpha)
plt.xticks(fontsize=5)
plt.yticks(fontsize=5)
plt.ylabel("Data/Model (Confirmed Cases)",fontsize=10)
plt.legend()
plt.ylim(0,1.95)

plt.subplot(332)
out1=np.divide(Dactifs, actif_sidarthe)
plt.plot(data_time,out1, 'b',label='Active Cases',linewidth=2)
plt.plot(data_time,Goodness,'b',linewidth=4)
plt.fill_between(data_time ,out1-uncert_actif,out1+uncert_actif,color='b',alpha=alpha)
plt.xticks(fontsize=5)
plt.yticks(fontsize=5)
plt.ylabel("Data/Model (Active Cases)",fontsize=10)
plt.legend()
plt.ylim(0,1.95)


plt.subplot(335)
out2=np.divide(Ddeads, E)
plt.plot(data_time,out2, 'gray',label='Extinct',linewidth=2)
plt.plot(data_time,Goodness, 'gray',linewidth=4)
plt.fill_between(data_time ,out2-uncert_dead,out2+uncert_dead,color='gray',alpha=alpha)
plt.xticks(fontsize=5)
plt.yticks(fontsize=5)
plt.xlabel("Time (days)",fontsize=10)
plt.ylabel('Data/Model (Extinct)',fontsize=10)
plt.legend()
plt.ylim(0,1.95)


plt.subplot(334)
out3=np.divide(Drecovereds, H)
plt.plot(data_time,out3, 'c',label='Healed',linewidth=2)
plt.plot(data_time,Goodness, 'c',linewidth=4)
plt.fill_between(data_time ,out3-uncert_recovered,out3+uncert_recovered,color='c',alpha=alpha)
plt.xticks(fontsize=5)
plt.yticks(fontsize=5)
plt.xlabel("Time (days)",fontsize=10)
plt.ylabel("Data/Model (Healed)",fontsize=10)
plt.legend()
plt.ylim(0,1.95)


plt.subplot(333)
out5=np.divide(data['Fration_fully_vaccinated'], V)
s = np.random.rand(*t2.shape) * 800 + 500
plt.plot(data_time,data['Goodnessfit'],'k.', markersize=10,label="Goodness of fitting",linewidth=4)
plt.plot(t2,out5[t2],'y.',markersize=10,label='Fully Vaccinated')
plt.xticks(fontsize=5)
plt.yticks(fontsize=5)
plt.xlabel("Time (days)",fontsize=10)
plt.ylabel("Data/Model (Fully Vaccinated)",fontsize=10)
plt.legend()
plt.ylim(0,2)
plt.xlim(450,724)


plt.subplot(336)
plt.plot(data_time ,U,'black', label='Unaffected',linewidth=2)
plt.plot(data_time ,H,'b', label='Healed',linewidth=2)
plt.xticks(fontsize=5)
plt.yticks(fontsize=5)
plt.xlabel("Time (days)",fontsize=10)
plt.legend(loc=4, prop={'size': 10})
plt.ylabel("Fractions of Population",fontsize=10)
plt.yscale("log")
plt.ylim(0, 10**-2)
plt.xlim(0, 750)



plt.subplots_adjust(hspace=.0)
plt.savefig("Combined plots Nigeria_updated", dpi=300, bbox_inches='tight')
# Out:
# /tmp/ipykernel_26937/3173130864.py:29: RuntimeWarning: invalid value encountered in true_divide
#   out2=np.divide(Ddeads, E)
# /tmp/ipykernel_26937/3173130864.py:42: RuntimeWarning: invalid value encountered in true_divide
#   out3=np.divide(Drecovereds, H)
# /tmp/ipykernel_26937/3173130864.py:77: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.ylim(0, 10**-2)
